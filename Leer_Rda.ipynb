# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/Cosas_Sueltas/blob/main/Leer_Rda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyreadr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 kB 11.2 MB/s eta 0:00:00
# ...

# %%
import requests
import pyreadr

# %%
r = requests.get('https://github.com/DataScienceForPublicPolicy/diys/raw/main/data/acs_health.Rda', allow_redirects=True)
with open ('acs_health.Rda','wb') as code:
  code.write(r.content)

# %%
df=pyreadr.read_r('/content/acs_health.Rda')["health"]

# %%
df
# Out:
#           id  no.coverage  age   race     sex   wage      cit      mar  \
# 0          1          0.0   60  White    Male   66.0  Citizen  Widowed
# 1          2          0.0   44  White    Male   40.0  Citizen  Married
# 2          3          0.0   40  White  Female   30.0  Citizen  Married
# 3          4          0.0   76  White    Male    0.0  Citizen  Married
# 4          5          0.0   71  White  Female    0.0  Citizen  Married
# ...      ...          ...  ...    ...     ...    ...      ...      ...
# 74800  74801          0.0   45  Asian  Female   21.3  Citizen  Married
# 74801  74802          0.0   80  Asian    Male    0.0  Citizen  Widowed
# 74802  74803          0.0   52  White  Female  195.0  Citizen  Married
# 74803  74804          0.0   52  White    Male   25.0  Citizen  Married
# 74804  74805          0.0   92  White  Female    0.0  Citizen  Widowed
#
#                        schl                 esr  puma
# 0                 HS Degree   Employed Civilian  2500
# ...
